# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data
#
# ### Plain Text

# %%
#!pip install -r requirements.txt

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "hieroglyph.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])
# Out:
# {
#     "success": {
#         "total": 1
#     },
#     "contents": {
#         "quotes": [
#             {
#                 "quote": "The best way to predict the future is to create it.",
#                 "length": "51",
#                 "author": "Abraham Lincoln",
#                 "tags": [
#                     "future",
#                     "inspire"
#                 ],
#                 "category": "inspire",
#                 "language": "en",
#                 "date": "2021-03-07",
#                 "permalink": "https://theysaidso.com/quote/abraham-lincoln-the-best-way-to-predict-the-future-is-to-create-it",
#                 "id": "Q3TIEXJ5M0DTgVJkdShQpAeF",
#                 "background": "https://theysaidso.com/img/qod/qod-inspire.jpg",
#                 "title": "Inspiring Quote of the day"
#             }
#         ]
#     },
#     "baseurl": "https://theysaidso.com",
#     "copyright": {
#         "year": 2023,
#         "url": "https://theysaidso.com"
#     }
# }
# The best way to predict the future is to create it.
# -- Abraham Lincoln

# %% [markdown]
# ## Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://news.ycombinator.com")
print(r.text)
# Out:
# <html lang="en" op="news"><head><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width, initial-scale=1.0"><link rel="stylesheet" type="text/css" href="news.css?6Uckzp3GMzbjuvDzjPjc">
#         <link rel="shortcut icon" href="favicon.ico">
#           <link rel="alternate" type="application/rss+xml" title="RSS" href="rss">
#         <title>Hacker News</title></head><body><center><table id="hnmain" border="0" cellpadding="0" cellspacing="0" width="85%" bgcolor="#f6f6ef">
#         <tr><td bgcolor="#ff6600"><table border="0" cellpadding="0" cellspacing="0" width="100%" style="padding:2px"><tr><td style="width:18px;padding-right:4px"><a href="https://news.ycombinator.com"><img src="y18.gif" width="18" height="18" style="border:1px white solid;"></a></td>
#                   <td style="line-height:12pt; height:10px;"><span class="pagetop"><b class="hnname"><a href="news">Hacker News</a></b>
#               <a href="newest">new</a> | <a href="front">past</a> | <a href="newcomments">comments</a> | <a href="ask">ask</a> | <a href="show">show</a> | <a href="jobs">jobs</a> | <a href="submit">submit</a>            </span></td><td style="text-align:right;padding-right:4px;"><span class="pagetop">
#                               <a href="login?goto=news">login</a>
#                           </span></td>
#               </tr></table></td></tr>
# <tr id="pagespace" title="" style="height:10px"></tr><tr><td><table border="0" cellpadding="0" cellspacing="0" class="itemlist">
#               <tr class='athing' id='26370572'>
#       <td align="right" valign="top" class="title"><span class="rank">1.</span></td>      <td valign="top" class="votelinks"><center><a id='up_26370572' href='vote?id=26370572&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://github.com/dolthub/dolt#dolt" class="storylink">Dolt is Git for Data: a SQL database that you can fork, clone, branch, merge</a><span class="sitebit comhead"> (<a href="from?site=github.com/dolthub"><span class="sitestr">github.com/dolthub</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_26370572">352 points</span> by <a href="user?id=crazypython" class="hnuser">crazypython</a> <span class="age"><a href="item?id=26370572">5 hours ago</a></span> <span id="unv_26370572"></span> | <a href="hide?id=26370572&amp;goto=news">hide</a> | <a href="item?id=26370572">125&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='26371818'>
#       <td align="right" valign="top" class="title"><span class="rank">2.</span></td>      <td valign="top" class="votelinks"><center><a id='up_26371818' href='vote?id=26371818&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://nodes.io/" class="storylink">Nodes.io – a new way to create with code</a><span class="sitebit comhead"> (<a href="from?site=nodes.io"><span class="sitestr">nodes.io</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_26371818">94 points</span> by <a href="user?id=triptych" class="hnuser">triptych</a> <span class="age"><a href="item?id=26371818">2 hours ago</a></span> <span id="unv_26371818"></span> | <a href="hide?id=26371818&amp;goto=news">hide</a> | <a href="item?id=26371818">32&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='26372407'>
#       <td align="right" valign="top" class="title"><span class="rank">3.</span></td>      <td valign="top" class="votelinks"><center><a id='up_26372407' href='vote?id=26372407&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.cbc.ca/news/canada/british-columbia/cell-phone-recovered-from-harrison-lake-1.5937753?cmp=rss" class="storylink">Functioning iPhone returned to owner after 6 months at bottom of lake</a><span class="sitebit comhead"> (<a href="from?site=cbc.ca"><span class="sitestr">cbc.ca</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_26372407">20 points</span> by <a href="user?id=Tiktaalik" class="hnuser">Tiktaalik</a> <span class="age"><a href="item?id=26372407">1 hour ago</a></span> <span id="unv_26372407"></span> | <a href="hide?id=26372407&amp;goto=news">hide</a> | <a href="item?id=26372407">1&nbsp;comment</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='26368939'>
#       <td align="right" valign="top" class="title"><span class="rank">4.</span></td>      <td valign="top" class="votelinks"><center><a id='up_26368939' href='vote?id=26368939&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="http://animatedengines.com/" class="storylink">Animated Engines</a><span class="sitebit comhead"> (<a href="from?site=animatedengines.com"><span class="sitestr">animatedengines.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_26368939">481 points</span> by <a href="user?id=marcodiego" class="hnuser">marcodiego</a> <span class="age"><a href="item?id=26368939">9 hours ago</a></span> <span id="unv_26368939"></span> | <a href="hide?id=26368939&amp;goto=news">hide</a> | <a href="item?id=26368939">60&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='26371848'>
#       <td align="right" valign="top" class="title"><span class="rank">5.</span></td>      <td valign="top" class="votelinks"><center><a id='up_26371848' href='vote?id=26371848&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://pmigdal.medium.com/dont-fight-flight-or-freeze-your-body-and-emotions-96f5aa30b299" class="storylink">Procrastination is flight, deadline is fight, freeze is staring at the screen</a><span class="sitebit comhead"> (<a href="from?site=pmigdal.medium.com"><span class="sitestr">pmigdal.medium.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_
nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='26369211'>
#       <td align="right" valign="top" class="title"><span class="rank">28.</span></td>      <td valign="top" class="votelinks"><center><a id='up_26369211' href='vote?id=26369211&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="http://dos.zone" class="storylink">Dos.Zone – interactive database of DOS games</a><span class="sitebit comhead"> (<a href="from?site=dos.zone"><span class="sitestr">dos.zone</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_26369211">50 points</span> by <a href="user?id=emersonrsantos" class="hnuser">emersonrsantos</a> <span class="age"><a href="item?id=26369211">8 hours ago</a></span> <span id="unv_26369211"></span> | <a href="hide?id=26369211&amp;goto=news">hide</a> | <a href="item?id=26369211">9&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='26342014'>
#       <td align="right" valign="top" class="title"><span class="rank">29.</span></td>      <td valign="top" class="votelinks"><center><a id='up_26342014' href='vote?id=26342014&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://launchfirst.substack.com/p/love-letters-of-intent" class="storylink">Love Letters of Intent</a><span class="sitebit comhead"> (<a href="from?site=launchfirst.substack.com"><span class="sitestr">launchfirst.substack.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_26342014">20 points</span> by <a href="user?id=StriverGuy" class="hnuser">StriverGuy</a> <span class="age"><a href="item?id=26342014">5 hours ago</a></span> <span id="unv_26342014"></span> | <a href="hide?id=26342014&amp;goto=news">hide</a> | <a href="item?id=26342014">1&nbsp;comment</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='26371823'>
#       <td align="right" valign="top" class="title"><span class="rank">30.</span></td>      <td valign="top" class="votelinks"><center><a id='up_26371823' href='vote?id=26371823&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="http://web.mit.edu/mitstep/projects/starlogo-tng.html" class="storylink" rel="nofollow">Starlogo TNG: The Next Generation (2009)</a><span class="sitebit comhead"> (<a href="from?site=web.mit.edu"><span class="sitestr">web.mit.edu</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_26371823">8 points</span> by <a href="user?id=jstrieb" class="hnuser">jstrieb</a> <span class="age"><a href="item?id=26371823">2 hours ago</a></span> <span id="unv_26371823"></span> | <a href="hide?id=26371823&amp;goto=news">hide</a> | <a href="item?id=26371823">3&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#             <tr class="morespace" style="height:10px"></tr><tr><td colspan="2"></td><td class="title"><a href="news?p=2" class="morelink" rel="next">More</a></td></tr>
#   </table>
# </td></tr>
# <tr><td><img src="s.gif" height="10" width="0"><table width="100%" cellspacing="0" cellpadding="1"><tr><td bgcolor="#ff6600"></td></tr></table><br><center><a href="https://www.ycombinator.com/apply/">
#         Applications are open for YC Summer 2021
#       </a></center><br><center><span class="yclinks"><a href="newsguidelines.html">Guidelines</a>
#         | <a href="newsfaq.html">FAQ</a>
#         | <a href="lists">Lists</a>
#         | <a href="https://github.com/HackerNews/API">API</a>
#         | <a href="security.html">Security</a>
#         | <a href="http://www.ycombinator.com/legal/">Legal</a>
#         | <a href="http://www.ycombinator.com/apply/">Apply to YC</a>
#         | <a href="mailto:hn@ycombinator.com">Contact</a></span><br><br><form method="get" action="//hn.algolia.com/">Search:
#           <input type="text" name="q" value="" size="17" autocorrect="off" spellcheck="false" autocapitalize="off" autocomplete="false"></form>
#             </center></td></tr>
#       </table></center></body><script type='text/javascript' src='hn.js?6Uckzp3GMzbjuvDzjPjc'></script></html>

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r.text))  # replace them with blank
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | past | comments | ask | show | jobs | submit
#                               login
#
#
#
#
#       1.      Dolt is Git for Data: a SQL database that you can fork, clone, branch, merge (github.com/dolthub)
#         352 points by crazypython 5 hours ago  | hide | 125&nbsp;comments
#
#
#       2.      Nodes.io – a new way to create with code (nodes.io)
#         94 points by triptych 2 hours ago  | hide | 32&nbsp;comments
#
#
#       3.      Functioning iPhone returned to owner after 6 months at bottom of lake (cbc.ca)
#         20 points by Tiktaalik 1 hour ago  | hide | 1&nbsp;comment
#
#
#       4.      Animated Engines (animatedengines.com)
#         481 points by marcodiego 9 hours ago  | hide | 60&nbsp;comments
#
#
#       5.      Procrastination is flight, deadline is fight, freeze is staring at the screen (pmigdal.medium.com)
#         68 points by stared 2 hours ago  | hide | 7&nbsp;comments
#
#
#       6.      FFMPEG from Zero to Hero (ffmpegfromzerotohero.com)
#         173 points by wilsonfiifi 5 hours ago  | hide | 58&nbsp;comments
#
#
#       7.      Cactus Comments: Federated web comments based on Matrix protocol (cactus.chat)
#         39 points by decrypt 2 hours ago  | hide | 4&nbsp;comments
#
#
#       8.      Thanks HN: Lessons learned after Google nearly killed my site (uploader.win)
#         416 points by uploaderwin 11 hours ago  | hide | 213&nbsp;comments
#
#
#       9.      Citus 10 brings columnar compression to Postgres (citusdata.com)
#         169 points by whitepoplar 8 hours ago  | hide | 49&nbsp;comments
#
#
#       10.      YouTuber Builds Working 3D-Printed Turbojet Engine and Tests It in His Attic (thedrive.com)
#         48 points by clouddrover 4 hours ago  | hide | 10&nbsp;comments
#
#
#       11.      Build Your Machine Today (vention.io)
#         31 points by alex_hirner 3 hours ago  | hide | 5&nbsp;comments
#
#
#       12.      Reality Is Perplexing Enough: An Interview with Jorge Luis Borges (1968) (commonwealmagazine.org)
#         24 points by keiferski 3 hours ago  | hide | 1&nbsp;comment
#
#
#       13.      The bizarre beasts living in Romania's poison cave (2015) (bbc.co.uk)
#         156 points by EndXA 9 hours ago  | hide | 30&nbsp;comments
#
#
#       14.      Standard Ruby 1.0 (testdouble.com)
#         61 points by ksec 4 hours ago  | hide | 43&nbsp;comments
#
#
#       15.      Breaking the “Lattice Barrier” for the Hidden Number Problem (iacr.org)
#         13 points by nanis 2 hours ago  | hide | discuss
#
#
#       16.      WordStar: A Writer's Word Processor (1996) (sfwriter.com)
#         89 points by Tomte 6 hours ago  | hide | 65&nbsp;comments
#
#
#       17.      What the Mouse Knows (simonsarris.substack.com)
#         51 points by exolymph 6 hours ago  | hide | 2&nbsp;comments
#
#
#       18.      ContentFly (YC W21) Is Hiring Product Managers and Product Designers (contentfly.com)
#         6 hours ago | hide
#
#
#       19.      Justified Variables: Words of the same length with related meanings (github.com/timvieira)
#         7 points by polm23 1 hour ago  | hide | 2&nbsp;comments
#
#
#       20.      Reflections on IDEA vs VS Code (archive.vn)
#         268 points by regexrex 13 hours ago  | hide | 329&nbsp;comments
#
#
#       21.      Lying to the Ghost in the Machine (antipope.org)
#         45 points by bergie 5 hours ago  | hide | 20&nbsp;comments
#
#
#       22.      What Is RPN? Why Did/Does HP Use RPN? Learning RPN (1999) (hpmuseum.org)
#         96 points by susam 8 hours ago  | hide | 89&nbsp;comments
#
#
#       23.      Download the Entire Wikimedia Database (wikimedia.org)
#         83 points by surround 6 hours ago  | hide | 48&nbsp;comments
#
#
#       24.      Launch HN: Lunatic (YC W21) – An Erlang Inspired WebAssembly Platform
#         132 points by withtypes 14 hours ago  | hide | 30&nbsp;comments
#
#
#       25.      Californians aren’t leaving the state en masse but are leaving San Francisco (latimes.com)
#         160 points by undefined1 2 hours ago  | hide | 197&nbsp;comments
#
#
#       26.      Show HN: PrograMaker – Visual Programming Platform (programaker.com)
#         52 points by kenkeiras 7 hours ago  | hide | 10&nbsp;comments
#
#
#       27.      Why Read Classic Books? (literaryforge.blog)
#         106 points by tosh 7 hours ago  | hide | 82&nbsp;comments
#
#
#       28.      Dos.Zone – interactive database of DOS games (dos.zone)
#         50 points by emersonrsantos 8 hours ago  | hide | 9&nbsp;comments
#
#
#       29.      Love Letters of Intent (launchfirst.substack.com)
#         20 points by StriverGuy 5 hours ago  | hide | 1&nbsp;comment
#
#
#       30.      Starlogo TNG: The Next Generation (2009) (web.mit.edu)
#         8 points by jstrieb 2 hours ago  | hide | 3&nbsp;comments
#
#             More
#
#
#
#         Applications are open for YC Summer 2021
#       Guidelines
#         | FAQ
#         | Lists
#         | API
#         | Security
#         | Legal
#         | Apply to YC
#         | ContactSearch:

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | past | comments | ask | show | jobs | submit
#                               login
#
#
#
#
#       1.      Dolt is Git for Data: a SQL database that you can fork, clone, branch, merge (github.com/dolthub)
#         352 points by crazypython 5 hours ago  | hide | 125 comments
#
#
#       2.      Nodes.io – a new way to create with code (nodes.io)
#         94 points by triptych 2 hours ago  | hide | 32 comments
#
#
#       3.      Functioning iPhone returned to owner after 6 months at bottom of lake (cbc.ca)
#         20 points by Tiktaalik 1 hour ago  | hide | 1 comment
#
#
#       4.      Animated Engines (animatedengines.com)
#         481 points by marcodiego 9 hours ago  | hide | 60 comments
#
#
#       5.      Procrastination is flight, deadline is fight, freeze is staring at the screen (pmigdal.medium.com)
#         68 points by stared 2 hours ago  | hide | 7 comments
#
#
#       6.      FFMPEG from Zero to Hero (ffmpegfromzerotohero.com)
#         173 points by wilsonfiifi 5 hours ago  | hide | 58 comments
#
#
#       7.      Cactus Comments: Federated web comments based on Matrix protocol (cactus.chat)
#         39 points by decrypt 2 hours ago  | hide | 4 comments
#
#
#       8.      Thanks HN: Lessons learned after Google nearly killed my site (uploader.win)
#         416 points by uploaderwin 11 hours ago  | hide | 213 comments
#
#
#       9.      Citus 10 brings columnar compression to Postgres (citusdata.com)
#         169 points by whitepoplar 8 hours ago  | hide | 49 comments
#
#
#       10.      YouTuber Builds Working 3D-Printed Turbojet Engine and Tests It in His Attic (thedrive.com)
#         48 points by clouddrover 4 hours ago  | hide | 10 comments
#
#
#       11.      Build Your Machine Today (vention.io)
#         31 points by alex_hirner 3 hours ago  | hide | 5 comments
#
#
#       12.      Reality Is Perplexing Enough: An Interview with Jorge Luis Borges (1968) (commonwealmagazine.org)
#         24 points by keiferski 3 hours ago  | hide | 1 comment
#
#
#       13.      The bizarre beasts living in Romania's poison cave (2015) (bbc.co.uk)
#         156 points by EndXA 9 hours ago  | hide | 30 comments
#
#
#       14.      Standard Ruby 1.0 (testdouble.com)
#         61 points by ksec 4 hours ago  | hide | 43 comments
#
#
#       15.      Breaking the “Lattice Barrier” for the Hidden Number Problem (iacr.org)
#         13 points by nanis 2 hours ago  | hide | discuss
#
#
#       16.      WordStar: A Writer's Word Processor (1996) (sfwriter.com)
#         89 points by Tomte 6 hours ago  | hide | 65 comments
#
#
#       17.      What the Mouse Knows (simonsarris.substack.com)
#         51 points by exolymph 6 hours ago  | hide | 2 comments
#
#
#       18.      ContentFly (YC W21) Is Hiring Product Managers and Product Designers (contentfly.com)
#         6 hours ago | hide
#
#
#       19.      Justified Variables: Words of the same length with related meanings (github.com/timvieira)
#         7 points by polm23 1 hour ago  | hide | 2 comments
#
#
#       20.      Reflections on IDEA vs VS Code (archive.vn)
#         268 points by regexrex 13 hours ago  | hide | 329 comments
#
#
#       21.      Lying to the Ghost in the Machine (antipope.org)
#         45 points by bergie 5 hours ago  | hide | 20 comments
#
#
#       22.      What Is RPN? Why Did/Does HP Use RPN? Learning RPN (1999) (hpmuseum.org)
#         96 points by susam 8 hours ago  | hide | 89 comments
#
#
#       23.      Download the Entire Wikimedia Database (wikimedia.org)
#         83 points by surround 6 hours ago  | hide | 48 comments
#
#
#       24.      Launch HN: Lunatic (YC W21) – An Erlang Inspired WebAssembly Platform
#         132 points by withtypes 14 hours ago  | hide | 30 comments
#
#
#       25.      Californians aren’t leaving the state en masse but are leaving San Francisco (latimes.com)
#         160 points by undefined1 2 hours ago  | hide | 197 comments
#
#
#       26.      Show HN: PrograMaker – Visual Programming Platform (programaker.com)
#         52 points by kenkeiras 7 hours ago  | hide | 10 comments
#
#
#       27.      Why Read Classic Books? (literaryforge.blog)
#         106 points by tosh 7 hours ago  | hide | 82 comments
#
#
#       28.      Dos.Zone – interactive database of DOS games (dos.zone)
#         50 points by emersonrsantos 8 hours ago  | hide | 9 comments
#
#
#       29.      Love Letters of Intent (launchfirst.substack.com)
#         20 points by StriverGuy 5 hours ago  | hide | 1 comment
#
#
#       30.      Starlogo TNG: The Next Generation (2009) (web.mit.edu)
#         8 points by jstrieb 2 hours ago  | hide | 3 comments
#
#             More
#
#
#
#         Applications are open for YC Summer 2021
#       Guidelines
#         | FAQ
#         | Lists
#         | API
#         | Security
#         | Legal
#         | Apply to YC
#         | ContactSearch:

# %%
# Find all articles
summaries = soup.find_all("tr", class_="athing")
summaries[0]
# Out:
# <tr class="athing" id="26370572">
#       <td align="right" class="title" valign="top"><span class="rank">1.</span></td>      <td class="votelinks" valign="top"><center><a href="vote?id=26370572&amp;how=up&amp;goto=news" id="up_26370572"><div class="votearrow" title="upvote"></div></a></center></td><td class="title"><a class="storylink" href="https://github.com/dolthub/dolt#dolt">Dolt is Git for Data: a SQL database that you can fork, clone, branch, merge</a><span class="sitebit comhead"> (<a href="from?site=github.com/dolthub"><span class="sitestr">github.com/dolthub</span></a>)</span></td></tr>

# %%
# Extract title
summaries[0].find("a", class_="storylink").get_text().strip()
# Out:
# 'Dolt is Git for Data: a SQL database that you can fork, clone, branch, merge'

# %%
# Find all articles, extract titles
articles = []
summaries = soup.find_all("tr", class_="athing")
for summary in summaries:
    title = summary.find("a", class_="storylink").get_text().strip()
    articles.append((title))

print(len(articles), "Article summaries found. Sample:")
print(articles[0])
# Out:
# 30 Article summaries found. Sample:
# Dolt is Git for Data: a SQL database that you can fork, clone, branch, merge

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
import os
import nltk
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)
# Out:
# Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers.

# %%
from nltk.tokenize import word_tokenize

# Split text into words using NLTK
words = word_tokenize(text)
print(words)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', '.', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', ',', 'which', 'catered', 'to', 'enterprise', 'customers', '.']

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Dr. Smith graduated from the University of Washington.', 'He later started an analytics firm called Lux, which catered to enterprise customers.']

# %%
# List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'ones', 'started', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaiss', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definit', 'watch', 'part', '2', 'chang', 'view', 'matrix', 'human', 'peopl', 'one', 'start', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'started', 'war', 'ai', 'bad', 'thing']
